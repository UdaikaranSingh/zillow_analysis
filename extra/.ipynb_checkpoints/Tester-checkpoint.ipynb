# %%
import sys
sys.path.append("..")

# %%
import numpy as np
import pandas as pd
from arcgis.gis import GIS
from arcgis.geocoding import geocode, batch_geocode
from ZillowUnivariate.univ_stats import SingleTableReader

# %%
gis = GIS(username='u1singh_UCSDOnline9', password='Udaikaran98')

# %%
file_dir = '/Volumes/GoogleDrive/Shared drives/Zillow1/data/raw/ZTrans_ZAsmt/unzipped_20191001/02'

# %%
columnsToUse = ['PropertyHouseNumber', 'PropertyHouseNumberExt','PropertyStreetPreDirectional',
               'PropertyStreetName','PropertyBuildingNumber','PropertyFullStreetAddress', 
                'PropertyCity','PropertyState','PropertyZip']

# %%
#ZTrans\PropertyInfo
prop_table = SingleTableReader("ZTrans", "PropertyInfo", file_dir).read(nrows = 1000, usecols = columnsToUse)

# %%
prop_table.describe()
# Out:
#        PropertyHouseNumber PropertyHouseNumberExt  \
# count                   13                      0
# unique                  10                      0
# top                      1                    NaN
# freq                     3                    NaN
#
#        PropertyStreetPreDirectional PropertyStreetName PropertyBuildingNumber  \
# count                             0                 13                      0
# unique                            0                 12                      0
# top                             NaN             MATRIX                    NaN
# freq                            NaN                  2                    NaN
#
#        PropertyFullStreetAddress PropertyCity PropertyState PropertyZip
# count                        148          151           272         151
# unique                       126           28             1          26
# top                  1 UNIAQ AVE     UNALASKA            AK       99685
# freq                           4           29           272          28

# %%
def define_address(row):
    state = row['PropertyState']
    zipCode = row['PropertyZip']
    city = row['PropertyCity']
    address = row['PropertyFullStreetAddress']
    if not pd.isna(state):
        if not pd.isna(zipCode):
            if not pd.isna(city):
                if not pd.isna(address):
                    return address + ',' + city + ',' + state + ',' + zipCode
                else:
                    return city + ',' + state + ',' + zipCode
            else:
                return state + ',' + zipCode
        else:
            return state
    else:
        return np.nan

# %%
prop_table['fixed_address'] = prop_table.apply(define_address, axis = 1)

# %%
addresses = list(prop_table.fixed_address)

# %%
addresses
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '666 CARIBOU DR,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  '649-649A PTARMIGAN WAY,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '77-79 AERIE ST,UNALASKA,AK,99685',
#  '107 CHOATE LN,UNALASKA,AK,99685',
#  '132 LOOP RD,UNALASKA,AK,99685',
#  '113 CHERNOFSKI,UNALASKA,AK,99692',
#  '194 CHERNOFSKI DR,UNALASKA,AK,99685',
#  '138 EAGLE DR,UNALASKA,AK,99685',
#  '28 DUTTON RD,UNALASKA,AK,99685',
#  '448 STEWARD RD,UNALASKA,AK,99685',
#  '107 LOWER HAYSTACK DR,UNALASKA,AK,99685',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  '125 SHORE AVE,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '501 DUTTON RD,UNALASKA,AK,99685',
#  '62-63 MAKUSHIN DR,DUTCH HARBOR,AK,99692',
#  '255 MAKUSHIN DR,UNALASKA,AK,99685',
#  '34 THOMPSON CIR,UNALASKA,AK,99685',
#  '144 AERIE DR,UNALASKA,AK,99685',
#  '240 EAGLE DR,UNALASKA,AK,99685',
#  '249-257 STEWARD RD,UNALASKA,AK,99685',
#  '48 CHERNOFSKI DR,DUTCH HARBOR,AK,99692',
#  '273 RAVEN WAY,UNALASKA,AK,99685',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '70 CHOATE LN,UNALASKA,AK,99685',
#  '104 LOOP RD,UNALASKA,AK,99685',
#  '43 ARMSTRONG CT,UNALASKA,AK,99685',
#  '26 S 3RD AVE,UNALASKA,AK,99685',
#  '133 AERIE DR,UNALASKA,AK,99685',
#  '115 GORBATCH ST,SAINT PAUL ISLAND,AK,99660',
#  '132 LOOP RD,UNALASKA,AK,99685',
#  '114 CHERNOFSKI DR,UNALASKA,AK,99685',
#  '29-31 THOMPSON CIR,UNALASKA,AK,99685',
#  '216 MELANIE AVE,WASILLA,AK,99658',
#  '111 HANAGITA,VALDEZ,AK,99666',
#  '195 BAY ST,SELDOVIA,AK,99563',
#  'EMMONAK,AK,99581',
#  '101 SHEPARD ST,SAINT MARYS,AK,99658',
#  '102 WESTDAHL ST,SAINT MARYS,AK,99658',
#  'ANNA LEAH AVE,SOLDOTNA,AK,99666',
#  '6431 WILLIWA CIR,ANCHORAGE,AK,99604',
#  '6 TRINITY DR,CHEVAK,AK,99563',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  '49 OSLUND DR,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1030 N TINA LN,WASILLA,AK,99554',
#  '6981 W WERNER DR,WASILLA,AK,99554',
#  '2621 E WANAMIRGO DR,WASILLA,AK,99554',
#  '450 W HERMITAGE DR,WASILLA,AK,99554',
#  '5610 S ROLLING DR,BIG LAKE,AK,99662',
#  '19-4 QETUNRAQ AVE,SAINT MARYS,AK,99658',
#  '21013 FOUR WHEEL DR,PETERS CREEK,AK,99657',
#  '1000 POLTES AVE,MARSHALL,AK,99585',
#  '21 PETERSON ST,MOUNTAIN VILLAGE,AK,99632',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '875 6TH AVE,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  '2 MILE LUTAK RD,HAINES,AK,99827',
#  '9B SKYLINE DR,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  '185 LAGOON ST,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  '1021-A CARIBOU DR,KOTZEBUE,AK,99752',
#  nan,
#  '32460 VIO RD,SOLDOTNA,AK,99658',
#  '1000 POLTES AVE,MARSHALL,AK,99585',
#  'YUKON WAY,EMMONAK,AK,99581',
#  'MAIN ST,HOOPER BAY,AK,99604',
#  '19-4 QETUNRAQ AVE,SAINT MARYS,AK,99658',
#  'PITKAS VIEW DR,PITKAS POINT,AK,99658',
#  '1 UNIAQ AVE,HOOPER BAY,AK,99604',
#  'AIRPORT RD,HOOPER BAY,AK,99604',
#  '19-4 QETUNGAWQ AVE,SAINT MARYS,AK,99658',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 AIRPORT RD,EMMONAK,AK,99581',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '6520 S ROOSEVELT,WASILLA,AK,99554',
#  '1 UNIAQ AVE,HOOPER BAY,AK,99604',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '398 LAGOON ST,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1002 KINGS RIDGE CIR,WASILLA,AK,99654',
#  '5893 E MORNING MIST DR,WASILLA,AK,99654',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '229 ALEX HATELY DR,BETHEL,AK,99554',
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  '9 MILE HAINES HWY,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'MARSHALL,AK,99585',
#  nan,
#  'NHN NSN,EMMONAK,AK,99581',
#  nan,
#  nan,
#  nan,
#  nan,
#  'NHN VALLEY ST,MOUNTAIN VILLAGE,AK,99632',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 TORNAGANUK RD,HOOPER BAY,AK,99604',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '308 TOWER RD,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1640 NERKA LOOP,DILLINGHAM,AK,99576',
#  '1735 NERKA LOOP,DILLINGHAM,AK,99576',
#  '1540 EMPEROR WAY,DILLINGHAM,AK,99576',
#  nan,
#  nan,
#  '4209 LAKE ALEKNAGIK RD,DILLINGHAM,AK,99576',
#  '1200 WOOD RIVER RD,DILLINGHAM,AK,99576',
#  '3357 CHUTHMOK DR,DILLINGHAM,AK,99576',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '699 PTARMIGAN WAY,KOTZEBUE,AK,99752',
#  '635 WOLVERINE DR,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2244 LAKE ALEKNAGIK RD,DILLINGHAM,AK,99576',
#  '9 5 ALEKNAGIK LAKE RD,DILLINGHAM,AK,99576',
#  nan,
#  '203 AIRPORT RD,DILLINGHAM,AK,99576',
#  nan,
#  nan,
#  nan,
#  'AK',
#  '571 F A A RD,HAINES,AK,99827',
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'EMMONAK,AK,99581',
#  '101 SHEPARD ST,SAINT MARYS,AK,99658',
#  '684 CARIBOU DR,KOTZEBUE,AK,99752',
#  nan,
#  '976-C MINERVA ST,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '102 WESTDAHL ST,SAINT MARYS,AK,99658',
#  '6 TRINITY DR,CHEVAK,AK,99563',
#  '1000 POLTES AVE,MARSHALL,AK,99585',
#  '21 PETERSON ST,MOUNTAIN VILLAGE,AK,99632',
#  '1000 POLTES AVE,MARSHALL,AK,99585',
#  'YUKON WAY,EMMONAK,AK,99581',
#  'MAIN ST,HOOPER BAY,AK,99604',
#  '19-4 QETUNRAQ AVE,SAINT MARYS,AK,99658',
#  'PITKAS VIEW DR,PITKAS POINT,AK,99658',
#  '3562 CANADA CT,DILLINGHAM,AK,99576',
#  '3325 WOOD RIVER RD,DILLINGHAM,AK,99576',
#  '3458 CANADA CT,DILLINGHAM,AK,99576',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 UNICORN,DILLINGHAM,AK,99576',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '676 CARIBOU DR,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 UNIAQ AVE,HOOPER BAY,AK,99604',
#  'AIRPORT RD,HOOPER BAY,AK,99604',
#  '19-4 QETUNGAWQ AVE,SAINT MARYS,AK,99658',
#  '1 UNIAQ AVE,HOOPER BAY,AK,99604',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  '248 BATTLE RD,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  '334 SAINT MARYS BLVD,SAINT MARYS,AK,99658',
#  nan,
#  nan,
#  nan,
#  '334 SAINT MARYS BLVD,SAINT MARYS,AK,99658',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '891 CARIBOU DR,KOTZEBUE,AK,99572',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '612 GRAYLING ST,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 MILE RIVER RD,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 FISHING LN,PORT ALSWORTH,AK,99653',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '1 AIRPORT RD,EMMONAK,AK,99581',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  '606 BISON ST,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '465 8TH AVE,KOTZEBUE,AK,99752',
#  nan,
#  '367 WHITTIER ST,KOTZEBUE,AK,99752',
#  nan,
#  '1320-A SHORE AVE,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '150 MONTGOMERY WAY,PALMER,AK,99645',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '419 6TH ST,KOTZEBUE,AK,99752',
#  '851-B 5TH AVE,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  '444 7TH AVE,KOTZEBUE,AK,99752',
#  nan,
#  '317 TUNDRA WAY,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '2532 S COGGIN DR,PALMER,AK,99645',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '3900 W SAINDON CT,WASILLA,AK,99623',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  '1 MILE SMALL TRACT RD,HAINES,AK,99827',
#  '1 5 MILE BEACH RD,HAINES,AK,99827',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  '446 MATRIX DR,HAINES,AK,99827',
#  '446 MATRIX DR,HAINES,AK,99827',
#  nan,
#  '185 LAGOON ST,KOTZEBUE,AK,99752',
#  '683-C&D CARIBOU DR,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '229 PARKS HWY,DENALI PARK,AK,99755',
#  nan,
#  nan,
#  '274.5 MILE PARKS HWY,HEALY,AK,99743',
#  nan,
#  nan,
#  nan,
#  nan,
#  '261&263 F ST,ANDERSON,AK,99744',
#  nan,
#  nan,
#  nan,
#  'MARSHALL,AK,99585',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'AK',
#  nan,
#  '474 8TH AVE,KOTZEBUE,AK,99752',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ALTAIR ST,HEALY,AK,99743',
#  'MP 251 PARKS HWY,HEALY,AK,99743',
#  'HEALY,AK,99743',
#  'MILE 133 5 DENALI HWY,CANTWELL,AK,99729',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '6347  Laura Madison St,Barrow,AK,99723',
#  nan,
#  nan,
#  '53 HAWLEY LN,UNALASKA,AK,99685',
#  '28 BARANOF ST,SAINT PAUL ISLAND,AK,99660',
#  '160 LOOP RD,UNALASKA,AK,99685',
#  '159 RIVERSIDE AVE,UNALASKA,AK,99685',
#  '48 CHOATE LN,UNALASKA,AK,99685',
#  '194 CHERNOFSKI,UNALASKA,AK,99685',
#  nan,
#  nan,
#  nan,
#  nan]

# %%
#results = batch_geocode(addresses)
# Out:
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# ...
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)
# Unsupported address: nan
# address should be a string (single line address) or dictionary (with address fields as keys)

# %%
df = pd.DataFrame(columns = ['score', 'latitude', 'longitude', 'address'])
for res in results:
    if (res['score'] == 0):
        row = [np.nan, np.nan, np.nan, np.nan]
    else:
        row = [res['score'], res['location']['x'],res['location']['y'], res['Match_addr']]
    df[len(df)] = row
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-7eee3a2366a3> in <module>
#       4         row = [np.nan, np.nan, np.nan, np.nan]
#       5     else:
# ----> 6         row = [res['score'], res['location']['x'],res['location']['y'], res['Match_addr']]
#       7     df[len(df)] = row
#
# KeyError: 'Match_addr'

# %%
results[100]
# Out:
# {'address': 'AK, Alaska',
#  'location': {'x': -151.00415781499996, 'y': 64.80808789800005},
#  'score': 100,
#  'attributes': {'ResultID': 100,
#   'Loc_name': 'World',
#   'Status': 'T',
#   'Score': 100,
#   'Match_addr': 'AK, Alaska',
#   'LongLabel': 'AK, USA',
#   'ShortLabel': 'AK',
#   'Addr_type': 'Locality',
#   'Type': 'State or Province',
#   'PlaceName': 'AK',
#   'Place_addr': 'Alaska',
#   'Phone': '',
#   'URL': '',
#   'Rank': 5,
#   'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'AddRange': '',
#   'Side': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StName': '',
#   'StType': '',
#   'StDir': '',
#   'BldgType': '',
#   'BldgName': '',
#   'LevelType': '',
#   'LevelName': '',
#   'UnitType': '',
#   'UnitName': '',
#   'SubAddr': '',
#   'StAddr': '',
#   'Block': '',
#   'Sector': '',
#   'Nbrhd': '',
#   'District': '',
#   'City': '',
#   'MetroArea': '',
#   'Subregion': '',
#   'Region': 'Alaska',
#   'RegionAbbr': 'AK',
#   'Territory': '',
#   'Zone': '',
#   'Postal': '',
#   'PostalExt': '',
#   'Country': 'USA',
#   'LangCode': 'ENG',
#   'Distance': 0,
#   'X': -151.00415781499996,
#   'Y': 64.80808789800005,
#   'DisplayX': -151.00415781499996,
#   'DisplayY': 64.80808789800005,
#   'Xmin': -169.99615781499995,
#   'Xmax': -132.01215781499997,
#   'Ymin': 45.81608789800005,
#   'Ymax': 83.80008789800006,
#   'ExInfo': ''}}

# %%
import os
from pathlib import Path
from subprocess import Popen
import boto3
import zipfile

# %%
s3 = boto3.client('s3')

# %%
download_bucket = "temp"
upload_bucket = "output"

TMPDIR = Path("zillow-data-raw/20191001/")
FIPS_table = ['2']

# %%
FipsFile = FIPS_table[0] + '.zip'
Key = '20191001/' + FipsFile
Filename = str(TMPDIR / FipsFile)
print(Filename)

# %%
# download zip file from s3 to ec2
s3.download_file(
    Bucket=download_bucket,
    Key=Key,
    Filename=Filename
)
